# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
with open(r'../../results/outcomes/S1-under-proportion.csv') as S1_under_prop:
    df_S1_under_prop=pd.read_csv(S1_under_prop)
df_S1_under_prop
# Out:
#     el_underground_proportion  br_underground_proportion
# 0                    0.338376                   0.338376
# 1                    0.892010                   0.338376
# 2                    0.917888                   0.338376
# 3                    0.938305                   0.338376
# 4                    0.957235                   0.338376
# 5                    0.971948                   0.338376
# 6                    0.982712                   0.338376
# 7                    0.989886                   0.338376
# 8                    0.992727                   0.338376
# 9                    0.994803                   0.338376
# 10                   0.997746                   0.338376
# 11                   0.999884                   0.338376
# 12                   1.000062                   0.338376
# 13                   1.000062                   0.338376
# 14                   1.000062                   0.338376
# ...

# %%
fig = plt.figure(figsize=(6,4))
fig.suptitle('I_NN Electric underground proportion',fontsize=20)
plt.plot(df_S1_under_prop.index, df_S1_under_prop['el_underground_proportion'], 'yo-', label='Electric')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.legend()
plt.savefig(r'../../figures/I_NN-E-Underprop.png',bbox_inches='tight', dpi=300)
plt.show()
fig = plt.figure(figsize=(6,4))
fig.suptitle('I_NN Broadband underground proportion',fontsize=20)
plt.plot(df_S1_under_prop.index, df_S1_under_prop['br_underground_proportion'], 'ro-', label='Broadband')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.savefig(r'../../figures/I_NN-B-Underprop.png',bbox_inches='tight', dpi=300)
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(6,4))
#fig.suptitle('I_NN Electric and broadband underground proportion',fontsize=20)
plt.plot(df_S1_under_prop.index, df_S1_under_prop['el_underground_proportion'], 'y', label='Electric')
plt.plot(df_S1_under_prop.index, df_S1_under_prop['br_underground_proportion'], 'r', label='Broadband')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.legend()
plt.savefig(r'../../figures/I_NN-EB-Underprop.png',bbox_inches='tight', dpi=300)
plt.show()

# %%
with open(r'../../results/outcomes/S2-under-proportion.csv') as S2_under_prop:
    df_S2_under_prop=pd.read_csv(S2_under_prop)
df_S2_under_prop
# Out:
#     el_underground_proportion  br_underground_proportion
# 0                    0.338376                   0.338376
# 1                    0.338376                   0.374049
# 2                    0.338376                   0.378199
# 3                    0.338376                   0.385539
# 4                    0.338376                   0.399104
# 5                    0.338376                   0.417152
# 6                    0.338376                   0.433349
# 7                    0.338376                   0.446036
# 8                    0.338376                   0.467324
# 9                    0.338376                   0.492365
# 10                   0.338376                   0.513577
# 11                   0.338376                   0.542449
# 12                   0.338376                   0.578999
# 13                   0.338376                   0.615293
# 14                   0.338376                   0.655924
# ...

# %%
fig = plt.figure(figsize=(6,4))
fig.suptitle('I_NC Electric underground proportion',fontsize=20)
plt.plot(df_S2_under_prop.index, df_S2_under_prop['el_underground_proportion'], 'yo-', label='Electric')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.legend()
plt.savefig(r'../../figures/I_NC-E-Underprop.png',bbox_inches='tight', dpi=300)
plt.show()
fig = plt.figure(figsize=(6,4))
fig.suptitle('I_NC Broadband underground proportion',fontsize=20)
plt.plot(df_S2_under_prop.index, df_S2_under_prop['br_underground_proportion'], 'ro-', label='Broadband')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.savefig(r'../../figures/I_NC-B-Underprop.png',bbox_inches='tight', dpi=300)
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(6,4))
#fig.suptitle('I_NC Electric underground proportion',fontsize=20)
plt.plot(df_S2_under_prop.index, df_S2_under_prop['el_underground_proportion'], 'y', label='Electric')
plt.plot(df_S2_under_prop.index, df_S2_under_prop['br_underground_proportion'], 'r', label='Broadband')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.legend()
plt.savefig(r'../../figures/I_NC-EB-Underprop.png',bbox_inches='tight', dpi=300)

# %%
with open(r'../../results/outcomes/S3-under-proportion.csv') as S3_under_prop:
    df_S3_under_prop=pd.read_csv(S3_under_prop)
df_S3_under_prop
# Out:
#     el_underground_proportion  br_underground_proportion
# 0                    0.338376                   0.338376
# 1                    0.338376                   0.892010
# 2                    0.338376                   0.917888
# 3                    0.338376                   0.938305
# 4                    0.338376                   0.957235
# 5                    0.338376                   0.971948
# 6                    0.338376                   0.982712
# 7                    0.338376                   0.989886
# 8                    0.338376                   0.992727
# 9                    0.338376                   0.994803
# 10                   0.338376                   0.997746
# 11                   0.338376                   0.999884
# 12                   0.338376                   1.000062
# 13                   0.338376                   1.000062
# 14                   0.338376                   1.000062
# ...

# %%
fig = plt.figure(figsize=(6,4))
fig.suptitle('I_NA Electric underground proportion',fontsize=20)
plt.plot(df_S3_under_prop.index, df_S3_under_prop['el_underground_proportion'], 'yo-', label='Electric')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.legend()
plt.savefig(r'../../figures/I_NA-E-Underprop.png',bbox_inches='tight', dpi=300)
plt.show()
fig = plt.figure(figsize=(6,4))
fig.suptitle('I_NA Broadband underground proportion',fontsize=20)
plt.plot(df_S3_under_prop.index, df_S3_under_prop['br_underground_proportion'], 'ro-', label='Broadband')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.savefig(r'../../figures/I_NA-B-Underprop.png',bbox_inches='tight', dpi=300)
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(6,4))
#fig.suptitle('I_NA Electric underground proportion',fontsize=20)
plt.plot(df_S3_under_prop.index, df_S3_under_prop['el_underground_proportion'], 'y', label='Electric')
plt.plot(df_S3_under_prop.index, df_S3_under_prop['br_underground_proportion'], 'r', label='Broadband')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.legend()
plt.savefig(r'../../figures/I_NA-EB-Underprop.png',bbox_inches='tight', dpi=300)
plt.show()

# %%
with open(r'../../results/outcomes/S4-under-proportion.csv') as S4_under_prop:
    df_S4_under_prop=pd.read_csv(S4_under_prop)
df_S4_under_prop
# Out:
#     el_underground_proportion  br_underground_proportion
# 0                    0.338376                   0.338376
# 1                    0.374049                   0.338376
# 2                    0.378199                   0.338376
# 3                    0.385539                   0.338376
# 4                    0.399104                   0.338376
# 5                    0.417152                   0.338376
# 6                    0.433349                   0.338376
# 7                    0.446036                   0.338376
# 8                    0.467324                   0.338376
# 9                    0.492365                   0.338376
# 10                   0.513577                   0.338376
# 11                   0.542449                   0.338376
# 12                   0.578999                   0.338376
# 13                   0.615293                   0.338376
# 14                   0.655924                   0.338376
# ...

# %%
fig = plt.figure(figsize=(6,4))
fig.suptitle('I_CN Electric underground proportion',fontsize=20)
plt.plot(df_S4_under_prop.index, df_S4_under_prop['el_underground_proportion'], 'yo-', label='Electric')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.legend()
plt.savefig(r'../../figures/I_CN-E-Underprop.png',bbox_inches='tight', dpi=300)
plt.show()
fig = plt.figure(figsize=(6,4))
fig.suptitle('I_CN Broadband underground proportion',fontsize=20)
plt.plot(df_S4_under_prop.index, df_S4_under_prop['br_underground_proportion'], 'ro-', label='Broadband')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.savefig(r'../../figures/I_CN-B-Underprop.png',bbox_inches='tight', dpi=300)
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(6,4))
#fig.suptitle('I_CN Electric underground proportion',fontsize=20)
plt.plot(df_S4_under_prop.index, df_S4_under_prop['el_underground_proportion'], 'y', label='Electric')
plt.plot(df_S4_under_prop.index, df_S4_under_prop['br_underground_proportion'], 'r', label='Broadband')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.legend()
plt.savefig(r'../../figures/I_CN-EB-Underprop.png',bbox_inches='tight', dpi=300)
plt.show()

# %%
with open(r'../../results/outcomes/S5-under-proportion.csv') as S5_under_prop:
    df_S5_under_prop=pd.read_csv(S5_under_prop)
df_S5_under_prop
# Out:
#     el_underground_proportion  br_underground_proportion
# 0                    0.338376                   0.338376
# 1                    0.892010                   0.338376
# 2                    0.917888                   0.338376
# 3                    0.938305                   0.338376
# 4                    0.957235                   0.338376
# 5                    0.971948                   0.338376
# 6                    0.982712                   0.338376
# 7                    0.989886                   0.338376
# 8                    0.992727                   0.338376
# 9                    0.994803                   0.338376
# 10                   0.997746                   0.338376
# 11                   0.999884                   0.338376
# 12                   1.000062                   0.338376
# 13                   1.000062                   0.338376
# 14                   1.000062                   0.338376
# ...

# %%
fig = plt.figure(figsize=(6,4))
fig.suptitle('I_AN Electric underground proportion',fontsize=20)
plt.plot(df_S5_under_prop.index, df_S5_under_prop['el_underground_proportion'], 'yo-', label='Electric')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.legend()
plt.savefig(r'../../figures/I_AN-E-Underprop.png',bbox_inches='tight', dpi=300)
plt.show()
fig = plt.figure(figsize=(6,4))
fig.suptitle('I_AN Broadband underground proportion',fontsize=20)
plt.plot(df_S5_under_prop.index, df_S5_under_prop['br_underground_proportion'], 'ro-', label='Broadband')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.savefig(r'../../figures/I_AN-B-Underprop.png',bbox_inches='tight', dpi=300)
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(6,4))
#fig.suptitle('I_AN Electric underground proportion',fontsize=20)
plt.plot(df_S5_under_prop.index, df_S5_under_prop['el_underground_proportion'], 'y', label='Electric')
plt.plot(df_S5_under_prop.index, df_S5_under_prop['br_underground_proportion'], 'r', label='Broadband')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.legend()
plt.savefig(r'../../figures/I_AN-EB-Underprop.png',bbox_inches='tight', dpi=300)
plt.show()

# %%
with open(r'../../results/outcomes/S6-to-S9-under-proportion.csv') as S69_under_prop:
    df_S69_under_prop=pd.read_csv(S69_under_prop)
df_S69_under_prop
# Out:
#     el_underground_proportion  br_underground_proportion
# 0                    0.338376                   0.338376
# 1                    0.374049                   0.374049
# 2                    0.378199                   0.378199
# 3                    0.385539                   0.385539
# 4                    0.399104                   0.399104
# 5                    0.417152                   0.417152
# 6                    0.433349                   0.433349
# 7                    0.446036                   0.446036
# 8                    0.467324                   0.467324
# 9                    0.492365                   0.492365
# 10                   0.513577                   0.513577
# 11                   0.542449                   0.542449
# 12                   0.578999                   0.578999
# 13                   0.615293                   0.615293
# 14                   0.655924                   0.655924
# ...

# %%
fig = plt.figure(figsize=(6,4))
fig.suptitle('J_CC and I_CC Electric underground proportion',fontsize=20)
plt.plot(df_S69_under_prop.index, df_S69_under_prop['el_underground_proportion'], 'yo-', label='Electric')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.legend()
plt.savefig(r'../../figures/J_CC and I_CC-E-Underprop.png',bbox_inches='tight', dpi=300)
plt.show()
fig = plt.figure(figsize=(6,4))
fig.suptitle('J_CC and I_CC Broadband underground proportion',fontsize=20)
plt.plot(df_S69_under_prop.index, df_S69_under_prop['br_underground_proportion'], 'ro-', label='Broadband')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.savefig(r'../../figures/J_CC and I_CC-B-Underprop.png',bbox_inches='tight', dpi=300)
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(6,4))
#fig.suptitle('J_CC and I_CC Electric underground proportion',fontsize=20)
plt.plot(df_S69_under_prop.index, df_S69_under_prop['el_underground_proportion'], 'y', label='Electric')
plt.plot(df_S69_under_prop.index, df_S69_under_prop['br_underground_proportion'], 'r', label='Broadband')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.legend()
plt.savefig(r'../../figures/J_CC and I_CC-EB-Underprop.png',bbox_inches='tight', dpi=300)
plt.show()

# %%
with open(r'../../results/outcomes/S10-to-S13-under-proportion.csv') as S1013_under_prop:
    df_S1013_under_prop=pd.read_csv(S1013_under_prop)
df_S1013_under_prop
# Out:
#     el_underground_proportion  br_underground_proportion
# 0                    0.338376                   0.338376
# 1                    0.892010                   0.892010
# 2                    0.917888                   0.917888
# 3                    0.938305                   0.938305
# 4                    0.957235                   0.957235
# 5                    0.971948                   0.971948
# 6                    0.982712                   0.982712
# 7                    0.989886                   0.989886
# 8                    0.992727                   0.992727
# 9                    0.994803                   0.994803
# 10                   0.997746                   0.997746
# 11                   0.999884                   0.999884
# 12                   1.000062                   1.000062
# 13                   1.000062                   1.000062
# 14                   1.000062                   1.000062
# ...

# %%
fig = plt.figure(figsize=(6,4))
fig.suptitle('J_AA and I_AA Electric underground proportion',fontsize=20)
plt.plot(df_S1013_under_prop.index, df_S1013_under_prop['el_underground_proportion'], 'yo-', label='Electric')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.legend()
plt.savefig(r'../../figures/J_AA and I_AA-E-Underprop.png',bbox_inches='tight', dpi=300)
plt.show()
fig = plt.figure(figsize=(6,4))
fig.suptitle('J_AA and I_AA Broadband underground proportion',fontsize=20)
plt.plot(df_S1013_under_prop.index, df_S1013_under_prop['br_underground_proportion'], 'ro-', label='Broadband')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.savefig(r'../../figures/J_AA and I_AA-B-Underprop.png',bbox_inches='tight', dpi=300)
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(6,4))
#fig.suptitle('J_AA and I_AA Electric underground proportion',fontsize=20)
plt.plot(df_S1013_under_prop.index, df_S1013_under_prop['el_underground_proportion'], 'y', label='Electric')
plt.plot(df_S1013_under_prop.index, df_S1013_under_prop['br_underground_proportion'], 'r', label='Broadband')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.legend()
plt.savefig(r'../../figures/J_AA and I_AA-EB-Underprop.png',bbox_inches='tight', dpi=300)
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
fig.suptitle('Electric underground proportion',fontsize=20)
plt.plot(df_S1_under_prop.index, df_S1_under_prop['el_underground_proportion'], 'bo-', label='S1')
plt.plot(df_S1_under_prop.index, df_S2_under_prop['el_underground_proportion'], 'g.-', label='S2')
plt.plot(df_S1_under_prop.index, df_S3_under_prop['el_underground_proportion'], 'r,-', label='S3')
plt.plot(df_S1_under_prop.index, df_S4_under_prop['el_underground_proportion'], 'cv-', label='S4')
plt.plot(df_S1_under_prop.index, df_S5_under_prop['el_underground_proportion'], 'm^-', label='S5')
plt.plot(df_S1_under_prop.index, df_S69_under_prop['el_underground_proportion'], 'y<-', label='S6')
plt.plot(df_S1_under_prop.index, df_S69_under_prop['el_underground_proportion'], 'k>-', label='S7')
plt.plot(df_S1_under_prop.index, df_S69_under_prop['el_underground_proportion'], color='lime', marker='1', linestyle='dashed',label='S8')
plt.plot(df_S1_under_prop.index, df_S69_under_prop['el_underground_proportion'], color='cornflowerblue', marker='2', linestyle='dashed', label='S9')
plt.plot(df_S1_under_prop.index, df_S1013_under_prop['el_underground_proportion'], color='darkorange', marker='*', linestyle='dashed', label='S10')
plt.plot(df_S1_under_prop.index, df_S1013_under_prop['el_underground_proportion'], color='plum', marker='+', linestyle='dashed', label='S11')
plt.plot(df_S1_under_prop.index, df_S1013_under_prop['el_underground_proportion'], color='peru', marker='s', linestyle='dashed', label='S12')
plt.plot(df_S1_under_prop.index, df_S1013_under_prop['el_underground_proportion'], color='teal', marker='p', linestyle='dashed', label='S13')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.legend()
plt.savefig(r'../../figures/electric-Underprop.png',bbox_inches='tight')
plt.show()

# %%
df_S2_under_prop['el_underground_proportion']
# Out:
# 0     0.338376
# 1     0.338376
# 2     0.338376
# 3     0.338376
# 4     0.338376
# 5     0.338376
# 6     0.338376
# 7     0.338376
# 8     0.338376
# 9     0.338376
# 10    0.338376
# 11    0.338376
# 12    0.338376
# 13    0.338376
# 14    0.338376
# 15    0.338376
# 16    0.338376
# 17    0.338376
# 18    0.338376
# 19    0.338376
# 20    0.338376
# 21    0.338376
# 22    0.338376
# 23    0.338376
# 24    0.338376
# 25    0.338376
# 26    0.338376
# 27    0.338376
# 28    0.338376
# 29    0.338376
# 30    0.338376
# 31    0.338376
# 32    0.338376
# 33    0.338376
# 34    0.338376
# 35    0.338376
# 36    0.338376
# 37    0.338376
# 38    0.338376
# 39    0.338376
# Name: el_underground_proportion, dtype: float64

# %%
fig = plt.figure(figsize=(10,8), dpi=400)
#fig.suptitle('Electric underground proportion',fontsize=20)
plt.plot(df_S1_under_prop.index, df_S5_under_prop['el_underground_proportion'], linestyle='-', color='green', label='IAN, IAA, CAA')
plt.plot(df_S1_under_prop.index, df_S4_under_prop['el_underground_proportion'], linestyle='-', color='blue', label='IMN, IMM, CMM')
plt.plot(df_S1_under_prop.index, df_S2_under_prop['el_underground_proportion'], linestyle='-', color='red', label='INN, INM, INA')

plt.xlabel('Year',fontsize=22)
plt.ylabel('Electric network underground proportion',fontsize=20)
plt.legend(fontsize=22)
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
plt.grid()
plt.savefig(r'../../figures/electric-Underprop.png', dpi=400, bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(10,8), dpi=400)
#fig.suptitle('Broadband underground proportion',fontsize=20)
plt.plot(df_S1_under_prop.index, df_S3_under_prop['br_underground_proportion'], linestyle='-', color='green',label='INA, IAA, CAA')
plt.plot(df_S1_under_prop.index, df_S2_under_prop['br_underground_proportion'], linestyle='-', color='blue',label='INM, IMM, CMM')
plt.plot(df_S1_under_prop.index, df_S1_under_prop['br_underground_proportion'], linestyle='-', color='red',label='INN, IMN, IAN')

plt.xlabel('Year',fontsize=22)
plt.ylabel('Broadband network underground proportion',fontsize=20)
plt.legend(fontsize=22)
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
plt.grid()
plt.savefig(r'../../figures/broadband-Underprop.png',dpi=400, bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
fig.suptitle('Broadband underground proportion',fontsize=20)
plt.plot(df_S1_under_prop.index, df_S1_under_prop['br_underground_proportion'], 'bo', label='S1')
plt.plot(df_S1_under_prop.index, df_S2_under_prop['br_underground_proportion'], 'g.-', label='S2')
plt.plot(df_S1_under_prop.index, df_S3_under_prop['br_underground_proportion'], 'r,-', label='S3')
plt.plot(df_S1_under_prop.index, df_S4_under_prop['br_underground_proportion'], 'cv-', label='S4')
plt.plot(df_S1_under_prop.index, df_S5_under_prop['br_underground_proportion'], 'm^-', label='S5')
plt.plot(df_S1_under_prop.index, df_S69_under_prop['br_underground_proportion'], 'y<-', label='S6')
plt.plot(df_S1_under_prop.index, df_S69_under_prop['br_underground_proportion'], 'k>-', label='S7')
plt.plot(df_S1_under_prop.index, df_S69_under_prop['br_underground_proportion'], color='lime', marker='1', linestyle='dashed',label='S8')
plt.plot(df_S1_under_prop.index, df_S69_under_prop['br_underground_proportion'], color='cornflowerblue', marker='2', linestyle='dashed', label='S9')
plt.plot(df_S1_under_prop.index, df_S1013_under_prop['br_underground_proportion'], color='darkorange', marker='*', linestyle='dashed', label='S10')
plt.plot(df_S1_under_prop.index, df_S1013_under_prop['br_underground_proportion'], color='plum', marker='+', linestyle='dashed', label='S11')
plt.plot(df_S1_under_prop.index, df_S1013_under_prop['br_underground_proportion'], color='peru', marker='s', linestyle='dashed', label='S12')
plt.plot(df_S1_under_prop.index, df_S1013_under_prop['br_underground_proportion'], color='teal', marker='p', linestyle='dashed', label='S13')
plt.xlabel('Analysis year',fontsize=14)
plt.ylabel('Underground proportion',fontsize=14)
plt.savefig(r'../../figures/broadband-Underprop.png',bbox_inches='tight')
plt.legend()
plt.show()

# %%
with open(r'../../results/outcomes/Resilience/10 years/NPV-10years-all.csv') as ten_years:
    df_ten_years=pd.read_csv(ten_years)
df_ten_years
# Out:
#   strategy  net benefit  under_prop
# 0     I_NN -750819270.1    0.338376
# 1     I_NC -753262209.8    0.425976
# 2     I_NA -766093682.6    0.668061
# 3     I_CN -648655901.1    0.425976
# 4     I_AN -368311692.7    0.668061
# 5     J_CC -649459267.3    0.513577
# 6     I_CC -651098840.8    0.513577
# 7     J_AA -375317483.8    0.997746
# 8     I_AA -375317483.8    0.997746

# %%
import seaborn as sns
sns.scatterplot(data=df_ten_years, x="under_prop", y="net benefit", hue="strategy").set(title='Year 10')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Underground proportion')
plt.ylabel('Net benefit ($)')
plt.savefig(r'../../figures/resilience_10.png',bbox_inches='tight', dpi=300)

# %%
with open(r'../../results/outcomes/Resilience/20 years/NPV-20years-all.csv') as twenty_years:
    df_twenty_years=pd.read_csv(twenty_years)
df_twenty_years
# Out:
#   strategy   net benefit  under_prop
# 0     I_NN -1.040984e+09    0.605059
# 1     I_NC -1.045984e+09    0.605059
# 2     I_NA -1.057013e+09    0.669219
# 3     I_CN -8.054554e+08    0.605059
# 4     I_AN -5.253112e+08    0.669219
# 5     J_CC -8.072340e+08    0.871742
# 6     I_CC -8.104556e+08    0.871742
# 7     J_AA -5.330581e+08    1.000000
# 8     I_AA -5.413404e+08    1.000000

# %%
import seaborn as sns
sns.scatterplot(data=df_twenty_years, x="under_prop", y="net benefit", hue="strategy").set(title='Year 20')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Underground proportion')
plt.ylabel('Net benefit ($)')
plt.savefig(r'../../figures/resilience_20.png',bbox_inches='tight', dpi=300)

# %%
with open(r'../../results/outcomes/Resilience/30 years/NPV-30years-all.csv') as thirty_years:
    df_thirty_years=pd.read_csv(thirty_years)
df_thirty_years
# Out:
#   strategy   net benefit  under_prop
# 0     I_NN -1.152947e+09    0.668061
# 1     I_NC -1.158708e+09    0.668061
# 2     I_NA -1.169266e+09    0.669219
# 3     I_CN -8.615648e+08    0.668061
# 4     I_AN -5.859863e+08    0.669219
# 5     J_CC -8.638061e+08    0.997746
# 6     I_CC -8.673251e+08    0.997746
# 7     J_AA -5.940231e+08    1.000000
# 8     I_AA -6.023053e+08    1.000000

# %%
import seaborn as sns
sns.scatterplot(data=df_thirty_years, x="under_prop", y="net benefit", hue="strategy").set(title='Year 30')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Underground proportion')
plt.ylabel('Net benefit ($)')
plt.savefig(r'../../figures/resilience_30.png',bbox_inches='tight', dpi=300)

# %%
with open(r'../../results/outcomes/Resilience/40 years/NPV-40years-all.csv') as forty_years:
    df_forty_years=pd.read_csv(forty_years)
df_forty_years
# Out:
#   strategy   net benefit  under_prop
# 0     I_NN -1.193339e+09    0.669219
# 1     I_NC -1.199247e+09    0.669219
# 2     I_NA -1.209801e+09    0.669219
# 3     I_CN -8.834832e+08    0.669219
# 4     I_AN -6.079155e+08    0.669219
# 5     J_CC -8.858690e+08    1.000000
# 6     I_CC -8.893910e+08    1.000000
# 7     J_AA -6.160952e+08    1.000000
# 8     I_AA -6.243774e+08    1.000000

# %%
import seaborn as sns
sns.scatterplot(data=df_forty_years, x="under_prop", y="net benefit", hue="strategy").set(title='Year 40')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Underground proportion')
plt.ylabel('Net benefit ($)')
plt.savefig(r'../../figures/resilience_40.png',bbox_inches='tight', dpi=300)

# %%
with open(r'../../results/outcomes/Resilience/Line plot/resilience-all-years-net-benefit.csv') as net_benefit:
    df_net_benefit=pd.read_csv(net_benefit)

# %%
with open(r'../../results/outcomes/Resilience/Line plot/resilience-all-years-underground.csv') as under:
    df_under=pd.read_csv(under)

# %%
df_net_benefit.plot(kind='line', marker=".")
# Out:
# <AxesSubplot:>

# %%
with open(r'../../results/outcomes/Resilience/Line plot/I-NN.csv') as INN:
    df_INN=pd.read_csv(INN)

# %%
with open(r'../../results/outcomes/Resilience/Line plot/I-NC.csv') as INC:
    df_INC=pd.read_csv(INC)

# %%
with open(r'../../results/outcomes/Resilience/Line plot/I-NA.csv') as INA:
    df_INA=pd.read_csv(INA)

# %%
with open(r'../../results/outcomes/Resilience/Line plot/I-CN.csv') as ICN:
    df_ICN=pd.read_csv(ICN)

# %%
with open(r'../../results/outcomes/Resilience/Line plot/I-AN.csv') as IAN:
    df_IAN=pd.read_csv(IAN)

# %%
with open(r'../../results/outcomes/Resilience/Line plot/I-CC.csv') as ICC:
    df_ICC=pd.read_csv(ICC)

# %%
with open(r'../../results/outcomes/Resilience/Line plot/I-AA.csv') as IAA:
    df_IAA=pd.read_csv(IAA)

# %%
with open(r'../../results/outcomes/Resilience/Line plot/J-CC.csv') as JCC:
    df_JCC=pd.read_csv(JCC)

# %%
with open(r'../../results/outcomes/Resilience/Line plot/J-AA.csv') as JAA:
    df_JAA=pd.read_csv(JAA)

# %%
plt.scatter(df_INN['Year'], df_INN['Net benefit'], s = df_INN['Underground proportion'], color='#FB9A99')
plt.scatter(df_INC['Year'], df_INC['Net benefit'], s = df_INC['Underground proportion'], color='#FDBF6F')
plt.scatter(df_INA['Year'], df_INA['Net benefit'], s = df_INA['Underground proportion'], color='#FF7F00')
plt.scatter(df_ICN['Year'], df_ICN['Net benefit'], s = df_ICN['Underground proportion'], color='#CAB2D6')
plt.scatter(df_IAN['Year'], df_IAN['Net benefit'], s = df_IAN['Underground proportion'], color='#6A3D9A')
plt.scatter(df_ICC['Year'], df_ICC['Net benefit'], s = df_ICC['Underground proportion'], color='#A6CEE3')
plt.scatter(df_IAA['Year'], df_IAA['Net benefit'], s = df_IAA['Underground proportion'], color='#1F78B4')
plt.scatter(df_JCC['Year'], df_JCC['Net benefit'], s = df_JCC['Underground proportion'], color='#B2DF8A')
plt.scatter(df_JAA['Year'], df_JAA['Net benefit'], s = df_JAA['Underground proportion'], color='#33A02C')

# %%
fig, ax = plt.subplots(figsize=(30,20))
#INN
ax.plot(df_INN['Year'], df_INN['Net benefit'], color='#FB9A99')
ax.scatter(df_INN['Year'], df_INN['Net benefit'], s=1000*df_INN['Underground proportion'],color='#FB9A99', zorder=3)
#INC
ax.plot(df_INC['Year'], df_INC['Net benefit'], color='#FDBF6F')
ax.scatter(df_INC['Year'], df_INC['Net benefit'], s=1000*df_INC['Underground proportion'],color='#FDBF6F', zorder=3)
#INA
ax.plot(df_INA['Year'], df_INA['Net benefit'], color='#FF7F00')
ax.scatter(df_INA['Year'], df_INA['Net benefit'], s=1000*df_INA['Underground proportion'],color='#FF7F00', zorder=3)
#ICN
ax.plot(df_ICN['Year'], df_ICN['Net benefit'], color='#CAB2D6')
ax.scatter(df_ICN['Year'], df_ICN['Net benefit'], s=1000*df_ICN['Underground proportion'],color='#CAB2D6', zorder=3)
#INN
ax.plot(df_IAN['Year'], df_IAN['Net benefit'], color='#6A3D9A')
ax.scatter(df_IAN['Year'], df_IAN['Net benefit'], s=1000*df_IAN['Underground proportion'],color='#6A3D9A', zorder=3)
#INN
ax.plot(df_INN['Year'], df_INN['Net benefit'], color='#FB9A99')
ax.scatter(df_INN['Year'], df_INN['Net benefit'], s=1000*df_INN['Underground proportion'],color='#FB9A99', zorder=3)
#INN
ax.plot(df_ICC['Year'], df_ICC['Net benefit'], color='#A6CEE3')
ax.scatter(df_ICC['Year'], df_ICC['Net benefit'], s=1000*df_ICC['Underground proportion'],color='#A6CEE3', zorder=3)
#INN
ax.plot(df_IAA['Year'], df_IAA['Net benefit'], color='#1F78B4')
ax.scatter(df_IAA['Year'], df_IAA['Net benefit'], s=1000*df_IAA['Underground proportion'],color='#1F78B4', zorder=3)
#JCC
ax.plot(df_JCC['Year'], df_JCC['Net benefit'], color='#B2DF8A')
ax.scatter(df_JCC['Year'], df_JCC['Net benefit'], s=1000*df_JCC['Underground proportion'],color='#B2DF8A', zorder=3)
#JAA
ax.plot(df_JAA['Year'], df_JAA['Net benefit'], color='#33A02C')
ax.scatter(df_JAA['Year'], df_JAA['Net benefit'], s=1000*df_JAA['Underground proportion'],color='#33A02C', zorder=3)
a_val = 0.3

circ1 = mpatches.Patch( facecolor='#FB9A99', label='INN')
circ2= mpatches.Patch( facecolor='#FDBF6F', label='INC')
circ3 = mpatches.Patch(facecolor='#FF7F00', label='INA')
circ4 = mpatches.Patch( facecolor='#CAB2D6', label='ICN')
circ5= mpatches.Patch( facecolor='#6A3D9A', label='IAN')
circ6 = mpatches.Patch(facecolor='#A6CEE3', label='ICC')
circ7 = mpatches.Patch( facecolor='#1F78B4', label='IAA')
circ8= mpatches.Patch( facecolor='#B2DF8A', label='JCC')
circ9 = mpatches.Patch(facecolor='#33A02C', label='JAA')

leg1=ax.legend(handles = [circ1,circ2,circ3,circ4,circ5,circ6,circ7,circ8,circ9],fontsize=30, loc='upper left')
plt.tight_layout()

h = [plt.plot([],[], color="gray", marker="o", ms=i, ls="")[0] for i in (10,20,30)]
leg2=plt.legend(handles=h, labels=('','', ''), title='underground proportion', fontsize=30, loc='lower right')
plt.setp(leg2.get_title(),fontsize=30)
#leg2=plt.legend(handles=h, fontsize=30, loc='lower right')
#ax.legend(title='underground proportion')
ax.add_artist(leg1)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.xlabel("Year", fontsize=35)
plt.ylabel("Net benefit ($)", fontsize=35)
ax.xaxis.offsetText.set_fontsize(30)
ax.yaxis.offsetText.set_fontsize(30)
plt.grid()
plt.savefig(r'../../figures/under-integerated.png', dpi=400 ,bbox_inches='tight')
