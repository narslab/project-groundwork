# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# plotting statusquo strategy cost
with open(r'../../data/tidy/concord.csv') as concord:
    df_concord=pd.read_csv(concord)
    df_concord_variable=df_concord.filter(items=['total cost','dencity(#parcel/ft)','1 phase','SAND','CLAY','BLD_AREA/length','TOTAL_VAL/length'])
    #pd_concord_variable=pd_concord['total cost','dencity(#parcel/ft)','1 phase','SAND','CLAY','BLD_AREA','TOTAL_VAL']
pd.plotting.scatter_matrix(df_concord_variable)
plt.legend(fontsize=16)
plt.figure(figsize=(12, 12))
# Out:
# No handles with labels found to put in legend.

# %%
#plotting relationship between clay and sand
N=26
y = df_concord_variable['SAND']
x = df_concord_variable['CLAY']
colors = np.random.rand(N)
plt.title("relationship between SAND and CLAY")
plt.ylabel('SAND%')
plt.xlabel('CLAY%')
plt.legend(fontsize=16)
plt.scatter(x, y, c=colors, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#plotting relationship between cost and dencity(#parcel/ft)
N=26
y = df_concord_variable['total cost']
x = df_concord_variable['dencity(#parcel/ft)']
colors = np.random.rand(N)
plt.title("relationship between cost and dencity(#parcel/ft)")
plt.ylabel('cost($)')
plt.xlabel('#parcel/ft')
plt.legend(fontsize=16)
plt.scatter(x, y, c=colors, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#plotting relationship between cost and 1 phase status
N=26
y = df_concord_variable['total cost']
x = df_concord_variable['1 phase']
colors = np.random.rand(N)
plt.title("relationship between cost and 1 phase status")
plt.ylabel('cost($)')
plt.xlabel('1 phase status')
plt.legend(fontsize=16)
plt.scatter(x, y, c=colors, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#plotting relationship between cost and SAND%
N=26
y = df_concord_variable['total cost']
x = df_concord_variable['SAND']
colors = np.random.rand(N)
plt.title("relationship between cost and SAND%")
plt.ylabel('cost($)')
plt.xlabel('SAND%')
plt.legend(fontsize=16)
plt.scatter(x, y, c=colors, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#plotting relationship between cost and CLAY%
N=26
y = df_concord_variable['total cost']
x = df_concord_variable['CLAY']
colors = np.random.rand(N)
plt.title("relationship between cost and CLAY%")
plt.ylabel('cost($)')
plt.xlabel('CLAY%')
plt.legend(fontsize=16)
plt.scatter(x, y, c=colors, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#plotting relationship between cost and BLD_AREA/length
N=26
y = df_concord_variable['total cost']
x = df_concord_variable['BLD_AREA/length']
colors = np.random.rand(N)
plt.title("relationship between cost and BLD_AREA/length")
plt.ylabel('cost($)')
plt.xlabel('BLD_AREA/length')
plt.legend(fontsize=16)
plt.scatter(x, y, c=colors, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#plotting relationship between cost and TOTAL_VAL/length
N=26
y = df_concord_variable['total cost']
x = df_concord_variable['TOTAL_VAL/length']
colors = np.random.rand(N)
plt.title("relationship between cost and TOTAL_VAL/length")
plt.ylabel('cost($)')
plt.xlabel('TOTAL_VAL/length')
plt.legend(fontsize=16)
plt.scatter(x, y, c=colors, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.
