# %%
import geopandas as gpd

# %%
df = gpd.read_file('data/Statewide_parcels_SHP/L3_TAXPAR_POLY_ASSESS.shp')

# %%
df.columns
# Out:
# Index(['MAP_PAR_ID', 'LOC_ID', 'POLY_TYPE', 'MAP_NO', 'SOURCE', 'PLAN_ID',
#        'LAST_EDIT', 'BND_CHK', 'NO_MATCH', 'TOWN_ID', 'PROP_ID', 'BLDG_VAL',
#        'LAND_VAL', 'OTHER_VAL', 'TOTAL_VAL', 'FY', 'LOT_SIZE', 'LS_DATE',
#        'LS_PRICE', 'USE_CODE', 'SITE_ADDR', 'ADDR_NUM', 'FULL_STR', 'LOCATION',
#        'CITY', 'ZIP', 'OWNER1', 'OWN_ADDR', 'OWN_CITY', 'OWN_STATE', 'OWN_ZIP',
#        'OWN_CO', 'LS_BOOK', 'LS_PAGE', 'REG_ID', 'ZONING', 'YEAR_BUILT',
#        'BLD_AREA', 'UNITS', 'RES_AREA', 'STYLE', 'NUM_ROOMS', 'LOT_UNITS',
#        'STORIES', 'SHAPE_AREA', 'SHAPE_LEN', 'geometry'],
#       dtype='object')

# %%
df_concord = df.loc[df.TOWN_ID == 67]

# %%
df_concord
# Out:
#         MAP_PAR_ID            LOC_ID POLY_TYPE MAP_NO  SOURCE PLAN_ID  \
# 1262          2107  F_682887_2992644       FEE     9D  ASSESS    None
# 1353        2986-1  F_681563_2980927       FEE    14C  ASSESS    None
# 1527          1863  F_688344_2994292       FEE     8E  ASSESS    None
# 2543          2497  F_683094_2989244       FEE    10D  ASSESS    None
# 2551          1101  F_701532_2996352       FEE     7I  ASSESS    None
# ...            ...               ...       ...    ...     ...     ...
# 2408836    1985-31  F_686900_2999244       FEE     6E  ASSESS    None
# 2408837       1934  F_685600_2995674       FEE     7D  ASSESS    None
# 2408941     1999-2  F_683009_2996780       FEE     7D  ASSESS    None
# 2408942       1044  F_703820_2996764       FEE     7J  ASSESS    None
# 2409097       2822  F_682979_2988084       FEE    11D  ASSESS    None
#
#          LAST_EDIT BND_CHK NO_MATCH  TOWN_ID  ... BLD_AREA  UNITS  RES_AREA  \
# ...

# %%
df_concord.FULL_STR.unique()
# Out:
# array(['POND ST', 'OLD PICKARD RD', 'COBURN HILL RD', 'SHIRLEY ST',
#        'ARROWHEAD RD', 'PINE HILL LN', 'SUDBURY RD', 'ROLLINGWOOD LN',
#        'CENTRAL ST', 'STONE ROOT LN', 'LOWELL RD', 'COTTAGE ST', 'ASH ST',
#        'INDIAN SPRING RD', 'MUSKETAQUID RD', 'FAIRHAVEN RD', 'MAIN ST',
#        'ARENA TER', 'HARRINGTON AVE', 'BLACK DUCK RD', 'WOODLAND RD',
#        'PARK LN', 'HAWTHORNE LN', 'SPRING RD', 'NASHAWTUC RD',
#        'HAYWARD MILL RD', 'MARTHAS POINT RD', 'HUBBARD ST',
#        'CAMBRIDGE TPKE', 'BEDFORD ST', 'NASHOBA RD', 'PILGRIM RD',
#        'ALDEN RD', 'WALDEN ST', 'POPE RD', 'LANG ST', 'PLAINFIELD RD',
#        'DANA RD', 'RIVERDALE RD', 'ASSABET AVE', 'RANGE RD',
#        'LAWS BROOK RD', 'BLUE JAY DR', 'WESTFORD RD', 'THOREAU ST',
#        'PETER SPRING RD', 'MONUMENT ST', 'DOVER ST', 'BRUCE RD',
#        'SEYMOUR ST', 'OAK HILL CIR', 'CREST ST', 'SOUTHFIELD RD',
#        'GROVE ST', 'SPENCER BROOK RD', 'FITCHBURG TPKE', 'BELKNAP ST',
# ...

# %%
df_concord.to_csv('data/concord_parcel_df.csv')

# %%
df_concord.loc[df.FULL_STR=='ELM ST']
# Out:
#         MAP_PAR_ID            LOC_ID POLY_TYPE MAP_NO  SOURCE PLAN_ID  \
# 118596        1832  F_689189_2993713       FEE     8F  ASSESS    None
# 215774        3799  F_688383_2993692       FEE     8E  ASSESS    None
# 275643      1769-3  F_692055_2992774       FEE     9F  ASSESS    None
# 313909      1797-1  F_689845_2993514       FEE     8F  ASSESS    None
# 390926      1769-1  F_691789_2992768       FEE     9F  ASSESS    None
# ...            ...               ...       ...    ...     ...     ...
# 2218138       1846  F_688418_2993929       FEE     8E  ASSESS    None
# 2298767     1899-1  F_686035_2994801       FEE     8E  ASSESS    None
# 2314819       1843  F_688702_2993832       FEE     8E  ASSESS    None
# 2406433       1917  F_684722_2995276       FEE     8D  ASSESS    None
# 2408941     1999-2  F_683009_2996780       FEE     7D  ASSESS    None
#
#          LAST_EDIT BND_CHK NO_MATCH  TOWN_ID  ... BLD_AREA  UNITS  RES_AREA  \
# ...
