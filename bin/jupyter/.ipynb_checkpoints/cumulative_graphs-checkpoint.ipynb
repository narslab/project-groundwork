# %%
import pandas as pd
import os
import sys
sys.path.append("../python/")
import csv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
with open(r'../../results/outcomes/sensitivity-result-statusquo.csv') as ss:
    sensitivity_statusQuo=pd.read_csv(ss)

# %%
sensitivity_statusQuo
# Out:
#                        Parameter  \
# 0                              r
# 1           over_corridor_length
# 2          under_corridor_length
# 3                  over_replcost
# 4                 under_replcost
# 5            overhead_proportion
# 6                  over_lifespan
# 7                 under_lifespan
# 8    over_om_percentage_replcost
# 9   under_om_percentage_replcost
# 10                  length_shape
# 11                  length_scale
# 12                     age_shape
# 13                     age_scale
#
#     %change in cost resulted from +%10 change in parameter  \
# 0                                           -9.934647
# 1                                            0.000000
# 2                                            0.000000
# 3                                            1.717190
# 4                                            7.355160
# 5                                          -10.467071
# 6                                           -1.563805
# ...

# %%
sensitivity_statusQuo[["%change in cost resulted from +%10 change in parameter", "%change in cost resulted from -%10 change in parameter"]] = sensitivity_statusQuo[["%change in cost resulted from +%10 change in parameter", "%change in cost resulted from -%10 change in parameter"]].apply(pd.to_numeric)

# %%
sns.set(style='darkgrid')
sns.set(rc={'figure.figsize':(11.7,8.27)})

# creating a dataframe
df = pd.DataFrame()
df['input'] = [sensitivity_statusQuo.iloc[7][0],sensitivity_statusQuo.iloc[0][0],sensitivity_statusQuo.iloc[5][0],sensitivity_statusQuo.iloc[13][0],sensitivity_statusQuo.iloc[10][0],sensitivity_statusQuo.iloc[12][0],sensitivity_statusQuo.iloc[11][0],sensitivity_statusQuo.iloc[4][0],sensitivity_statusQuo.iloc[6][0],sensitivity_statusQuo.iloc[9][0],sensitivity_statusQuo.iloc[3][0],sensitivity_statusQuo.iloc[8][0],sensitivity_statusQuo.iloc[1][0],sensitivity_statusQuo.iloc[2][0]]
df['+']=[round(sensitivity_statusQuo.iloc[7][1]),round(sensitivity_statusQuo.iloc[0][1]),round(sensitivity_statusQuo.iloc[5][1]),round(sensitivity_statusQuo.iloc[13][1]),round(sensitivity_statusQuo.iloc[10][1]),round(sensitivity_statusQuo.iloc[12][1]),round(sensitivity_statusQuo.iloc[11][1]),round(sensitivity_statusQuo.iloc[4][1]),round(sensitivity_statusQuo.iloc[6][1]),round(sensitivity_statusQuo.iloc[9][1]),round(sensitivity_statusQuo.iloc[3][1]),round(sensitivity_statusQuo.iloc[8][1]),round(sensitivity_statusQuo.iloc[1][1]),round(sensitivity_statusQuo.iloc[2][1])]
df['-']=[round(sensitivity_statusQuo.iloc[7][2]),round(sensitivity_statusQuo.iloc[0][2]),round(sensitivity_statusQuo.iloc[5][2]),round(sensitivity_statusQuo.iloc[13][2]),round(sensitivity_statusQuo.iloc[10][2]),round(sensitivity_statusQuo.iloc[12][2]),round(sensitivity_statusQuo.iloc[11][2]),round(sensitivity_statusQuo.iloc[4][2]),round(sensitivity_statusQuo.iloc[6][2]),round(sensitivity_statusQuo.iloc[9][2]),round(sensitivity_statusQuo.iloc[3][2]),round(sensitivity_statusQuo.iloc[8][2]),round(sensitivity_statusQuo.iloc[1][2]),round(sensitivity_statusQuo.iloc[2][2])]

#now stacking it
df2 = pd.melt(df, id_vars ='input', var_name='type of change', value_name='change in the output' )

fig, ax = plt.subplots()
for typ, df in zip(df2['type of change'].unique(),df2.groupby('type of change')):
    ax.barh(df[1]['input'], df[1]['change in the output'], height=0.3, label=typ)
ax.legend(title = 'type of change')

# %%
with open(r'../../results/outcomes/sensitivity-result-under.csv') as su:
    sensitivity_under=pd.read_csv(su)

# %%
sensitivity_under
# Out:
#                        Parameter  \
# 0                              r
# 1           over_corridor_length
# 2          under_corridor_length
# 3                  over_replcost
# 4                 under_replcost
# 5            overhead_proportion
# 6                  over_lifespan
# 7                 under_lifespan
# 8    over_om_percentage_replcost
# 9   under_om_percentage_replcost
# 10                  length_shape
# 11                  length_scale
# 12                     age_shape
# 13                     age_scale
#
#     %change in cost resulted from +%10 change in parameter  \
# 0                                          -13.306930
# 1                                           -0.248234
# 2                                            0.496468
# 3                                            1.377883
# 4                                            7.513519
# 5                                           -9.027744
# 6                                           -6.720925
# ...

# %%
sns.set(style='darkgrid')
sns.set(rc={'figure.figsize':(11.7,8.27)})

# creating a dataframe
df = pd.DataFrame()
df['input'] = [sensitivity_under.iloc[7][0],sensitivity_under.iloc[13][0],sensitivity_under.iloc[6][0],sensitivity_under.iloc[0][0],sensitivity_statusQuo.iloc[12][0],sensitivity_under.iloc[10][0],sensitivity_under.iloc[5][0],sensitivity_under.iloc[11][0],sensitivity_under.iloc[4][0],sensitivity_statusQuo.iloc[9][0],sensitivity_under.iloc[3][0],sensitivity_under.iloc[8][0],sensitivity_under.iloc[2][0],sensitivity_under.iloc[1][0]]
df['+']=[round(sensitivity_under.iloc[7][1]),round(sensitivity_under.iloc[13][1]),round(sensitivity_under.iloc[6][1]),round(sensitivity_under.iloc[0][1]),round(sensitivity_under.iloc[12][1]),round(sensitivity_under.iloc[10][1]),round(sensitivity_under.iloc[5][1]),round(sensitivity_under.iloc[11][1]),round(sensitivity_under.iloc[4][1]),round(sensitivity_under.iloc[9][1]),round(sensitivity_under.iloc[3][1]),round(sensitivity_under.iloc[8][1]),round(sensitivity_under.iloc[2][1]),round(sensitivity_under.iloc[1][1])]
df['-']=[round(sensitivity_under.iloc[7][2]),round(sensitivity_under.iloc[13][2]),round(sensitivity_under.iloc[6][2]),round(sensitivity_under.iloc[0][2]),round(sensitivity_under.iloc[12][2]),round(sensitivity_under.iloc[10][2]),round(sensitivity_under.iloc[5][2]),round(sensitivity_under.iloc[11][2]),round(sensitivity_under.iloc[4][2]),round(sensitivity_under.iloc[9][2]),round(sensitivity_under.iloc[3][2]),round(sensitivity_under.iloc[8][2]),round(sensitivity_under.iloc[2][2]),round(sensitivity_under.iloc[1][2])]

#now stacking it
df2 = pd.melt(df, id_vars ='input', var_name='type of change', value_name='change in the output' )

fig, ax = plt.subplots()
for typ, df in zip(df2['type of change'].unique(),df2.groupby('type of change')):
    ax.barh(df[1]['input'], df[1]['change in the output'], height=0.3, label=typ)
ax.legend(title = 'type of change')

# %%
###plotting cost elements for statusQuo strategy
#fig = plt.figure()
plt.rcParams["figure.figsize"] = (12, 8)
plt.style.use('ggplot')

x = ['Lifecycle Infrastructure', 'Environmental Restoration', 'Safety', 'Total Cost']
cost = [total_infrastructre_statusQuo, total_environmental_statusQuo, total_safety_statusQuo, total_total_statusQuo]

x_pos = [i for i, _ in enumerate(x)]

plt.bar(x_pos, cost, color='green')

plt.xlabel("Cost Elements", fontsize=14)
plt.ylabel("Cost Output ($10millions)",fontsize=14)
plt.title("Net Preset Cost Output of statusQuo strategy", fontsize=20)

plt.xticks(x_pos, x)
plt.figsize=(28,25)
plt.show()
#savefig('test.png', bbox_inches='tight')

# %%
###Calculating net present value of infrastructure, environmental, safety and total cost for undergrounding after lifespan strategy
df_net_present_statusQuo=Analyze_Result.aggregate_through_years_under_after_lifespan()
net_present_value_lifecycle_infrastructure_cost_under=[]
net_present_value_environmental_cost_under=[]
net_present_value_safety_cost_under=[]
net_present_value_total_cost_under=[]
for index, row in df_net_present_statusQuo.iterrows():
    net_present_value_lifecycle_infrastructure_cost_under.append(row['total infra']/(1+Network.r)**index)
    net_present_value_environmental_cost_under.append(row['environmental restoration']/(1+Network.r)**index)
    net_present_value_safety_cost_under.append(row['total safety']/(1+Network.r)**index)
    net_present_value_total_cost_under.append(row['total cost']/(1+Network.r)**index)
total_infrastructre_under=sum(net_present_value_lifecycle_infrastructure_cost)
total_environmental_under=sum(net_present_value_environmental_cost)
total_safety_under=sum(net_present_value_safety_cost)
total_total_under=sum(net_present_value_total_under_after_lifespan_strategy_cost)

# %%
print(total_infrastructre_under)
print(total_environmental_under)
print(total_safety_under)
print(total_total_under)
# Out:
# 12825250.760085173
# 0.0
# 1291084.4113304813
# 14116335.171415646

# %%
###plotting cost elements for statusQuo strategy
plt.rcParams["figure.figsize"] = (12, 8)
plt.style.use('ggplot')

x = ['Lifecycle Infrastructure', 'Environmental Restoration', 'Safety', 'Total Cost']
cost = [total_infrastructre_under, total_environmental_under, total_safety_under, total_total_under]

x_pos = [i for i, _ in enumerate(x)]

plt.bar(x_pos, cost, color='gold')

plt.xlabel("Cost Elements", fontsize=14)
plt.ylabel("Cost Output ($10millions)",fontsize=14)
plt.title("Net Preset Cost Output of undergrounding after lifespan", fontsize=20)

plt.xticks(x_pos, x)
plt.figsize=(28,25)
plt.show()

# %%
print(total_infrastructre_additional=total_infrastructre_under-total_infrastructre_statusQuo)
print(total_environmental_additional=total_environmental_under-total_environmental_statusQuo)
print(total_safety_additional=total_safety_under-total_safety_statusQuo)
print(total_total_additional=total_total_under-total_total_statusQuo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e58f856b33a9> in <module>
# ----> 1 print(total_infrastructre_additional=total_infrastructre_under-total_infrastructre_statusQuo)
#       2 print(total_environmental_additional=total_environmental_under-total_environmental_statusQuo)
#       3 print(total_safety_additional=total_safety_under-total_safety_statusQuo)
#       4 print(total_total_additional=total_total_under-total_total_statusQuo)
#
# NameError: name 'total_infrastructre_under' is not defined

# %%
###plotting cost elements for statusQuo strategy
plt.rcParams["figure.figsize"] = (12, 8)
plt.style.use('ggplot')

x = ['Lifecycle Infrastructure', 'Environmental Restoration', 'Safety', 'Total Cost']
cost = [total_infrastructre_additional, total_environmental_additional, total_safety_additional, total_total_additional]

x_pos = [i for i, _ in enumerate(x)]

plt.bar(x_pos, cost, color='red')

plt.xlabel("Cost Elements", fontsize=14)
plt.ylabel("Cost Output",fontsize=14)
plt.title("Net preset additional cost output of undergrounding after lifespan", fontsize=20)

plt.xticks(x_pos, x)
plt.figsize=(28,25)
plt.show()
