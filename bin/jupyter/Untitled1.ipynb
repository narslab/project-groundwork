# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics
  
# Plot between -10 and 10 with .001 steps.
x_axis = np.arange(-4, 1, 0.01)
  
# Calculating mean and standard deviation
#mean = statistics.mean(x_axis)
#sd = statistics.stdev(x_axis)
  
plt.plot(x_axis, norm.pdf(x_axis, -1.5524671002565889, 0.7638484639407965))
plt.show()

# %%
mu, sigma = -1.5524671002565889, 0.7638484639407965 # mean and standard deviation
s = np.random.normal(mu, sigma)
s
# Out:
# -1.7411174215313951
