# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
# plotting the scatter plot matrix
with open(r'../../data/tidy/concord_streets_data.csv') as concord:
    df_concord=pd.read_csv(concord)
    df_concord_variable=df_concord.filter(items=['total cost','density(#parcel/ft)','1 phase','SAND_mean','CLAY_mean','BLD_AREA/length','TOTAL_VAL/length','SAND_max','CLAY_max','UNITS_density','residential_mode','residential_100%','log_density','log_CLAY'])
    #pd_concord_variable=pd_concord['total cost','dencity(#parcel/ft)','1 phase','SAND','CLAY','BLD_AREA','TOTAL_VAL']
pd.plotting.scatter_matrix(df_concord_variable, figsize  = [30, 30], diagonal='kde',s=400)
plt.savefig(r'../../figures/scatter-plot-matrix.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
data = df_concord_variable
# use the scatterplot function to build the bubble map
sns.scatterplot(data=data, x=df_concord_variable['log_density'], y=df_concord_variable['total cost'], size=df_concord_variable['1 phase'], legend=False, sizes=(10, 200))
plt.title("relationship between cost, Log_density and 1 phase")
# show the graph
plt.show()

# %%
#plotting relationship between log_density and residential_street_type
#N=26
y = df_concord['log_density']
x = df_concord['street_type']
#colors = np.random.rand(N)
#plt.title("relationship between log_density and street_type")
plt.ylabel('log_density')
plt.xlabel('street_type')
#plt.legend(fontsize=16)
plt.scatter(x, y, alpha=0.5)
plt.savefig(r'../../figures/relationship between log_density and street_type.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#plotting relationship between cost and residential_street_type
#N=26
y = df_concord['total cost']
x = df_concord['residential_street_type']
#colors = np.random.rand(N)
plt.title("relationship between cost and residential_street_type")
plt.ylabel('cost($)')
plt.xlabel('residential_street_type')
plt.legend(fontsize=16)
plt.scatter(x, y, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# plotting statusquo strategy cost
with open(r'../../data/tidy/concord_streets_data.csv') as concord:
    df_concord=pd.read_csv(concord)
    df_concord_variable=df_concord.filter(items=['total cost','density(#parcel/ft)','1 phase','SAND_mean','CLAY_mean','BLD_AREA/length','TOTAL_VAL/length','log_density','SAND_max','CLAY_max','log_SAND','log_CLAY','UNITS_density','residential_mode','residential_100%'])
    #pd_concord_variable=pd_concord['total cost','dencity(#parcel/ft)','1 phase','SAND','CLAY','BLD_AREA','TOTAL_VAL']
pd.plotting.scatter_matrix(df_concord_variable, figsize  = [25, 25])
plt.figure(figsize=(25, 25))

# %%
#plotting relationship between clay and sand
#N=26
y = df_concord_variable['SAND_mean']
x = df_concord_variable['CLAY_mean']
#colors = np.random.rand(N)
plt.title("relationship between SAND_mean and CLAY_mean")
plt.ylabel('SAND_mean%')
plt.xlabel('CLAY_mean%')
plt.legend(fontsize=16)
plt.scatter(x, y, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#plotting relationship between cost and dencity(#parcel/ft)
#N=26
y = df_concord_variable['total cost']
x = df_concord_variable['density(#parcel/ft)']
#colors = np.random.rand(N)
plt.title("relationship between cost and density(#parcel/ft)")
plt.ylabel('cost($)')
plt.xlabel('#parcel/ft')
plt.legend(fontsize=16)
plt.scatter(x, y, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#plotting relationship between cost and 1 phase status
#N=26
y = df_concord_variable['total cost']
x = df_concord_variable['1 phase']
#colors = np.random.rand(N)
plt.title("relationship between cost and 1 phase status")
plt.ylabel('cost($)')
plt.xlabel('1 phase status')
plt.legend(fontsize=16)
plt.scatter(x, y, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#plotting relationship between cost and SAND%
#N=26
y = df_concord_variable['total cost']
x = df_concord_variable['SAND_mean']
#colors = np.random.rand(N)
plt.title("relationship between cost and SAND_mean%")
plt.ylabel('cost($)')
plt.xlabel('SAND%')
plt.legend(fontsize=16)
plt.scatter(x, y, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#plotting relationship between cost and log SAND%
#N=26
y = df_concord_variable['total cost']
x = np. log(df_concord_variable['SAND_mean'])
#colors = np.random.rand(N)
plt.title("relationship between cost and log SAND_mean%")
plt.ylabel('cost($)')
plt.xlabel('SAND%')
plt.legend(fontsize=16)
plt.scatter(x, y, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#plotting relationship between cost and CLAY%
#N=26
y = df_concord_variable['total cost']
x = df_concord_variable['CLAY_mean']
#colors = np.random.rand(N)
plt.title("relationship between cost and CLAY_mean%")
plt.ylabel('cost($)')
plt.xlabel('CLAY%')
plt.legend(fontsize=16)
plt.scatter(x, y, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#plotting relationship between cost and log CLAY%
#N=26
y = df_concord_variable['total cost']
x = np.log(df_concord_variable['CLAY_mean'])
#colors = np.random.rand(N)
plt.title("relationship between cost and log CLAY_mean%")
plt.ylabel('cost($)')
plt.xlabel('CLAY_mean%')
plt.legend(fontsize=16)
plt.scatter(x, y, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#plotting relationship between cost and BLD_AREA/length
#N=26
y = df_concord_variable['total cost']
x = df_concord_variable['BLD_AREA/length']
#colors = np.random.rand(N)
plt.title("relationship between cost and BLD_AREA/ft")
plt.ylabel('cost($)')
plt.xlabel('BLD_AREA/ft')
plt.legend(fontsize=16)
plt.scatter(x, y, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#plotting relationship between cost and TOTAL_VAL/length
#N=26
y = df_concord_variable['total cost']
x = df_concord_variable['TOTAL_VAL/length']
#colors = np.random.rand(N)
plt.title("relationship between cost and TOTAL_VAL/ft")
plt.ylabel('cost($)')
plt.xlabel('TOTAL_VAL/ft')
plt.legend(fontsize=16)
plt.scatter(x, y, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#plotting relationship between cost and dencity(#parcel/ft)
#N=26
y = df_concord_variable['total cost']
x = df_concord_variable['log_density']
#colors = np.random.rand(N)
plt.title("relationship between cost and log of density(#parcel/ft)")
plt.ylabel('cost($)')
plt.xlabel('#parcel/ft')
plt.legend(fontsize=16)
plt.scatter(x, y, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#plotting relationship between cost and dencity(#parcel/ft)
#N=26
y = df_concord_variable['total cost']
x = np.exp(df_concord_variable['density(#parcel/ft)'])
#colors = np.random.rand(N)
plt.title("relationship between cost and exp of density(#parcel/ft)")
plt.ylabel('cost($)')
plt.xlabel('#parcel/ft')
plt.legend(fontsize=16)
plt.scatter(x, y, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#plotting relationship between cost and dencity(#parcel/ft)
#N=26
y = df_concord_variable['total cost']
x = np.sqrt(df_concord_variable['density(#parcel/ft)'])
#colors = np.random.rand(N)
plt.title("relationship between cost and sqrt of density(#parcel/ft)")
plt.ylabel('cost($)')
plt.xlabel('#parcel/ft')
plt.legend(fontsize=16)
plt.scatter(x, y, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#plotting relationship between cost and TOTAL_VAL/length
y = df_concord_variable['total cost']
x= df_concord_variable['SAND_mean']/df_concord_variable['CLAY_mean']
plt.title("relationship between cost and SAND/mean/CLAY_mean")
plt.ylabel('cost($)')
plt.xlabel('TOTAL_VAL/length')
plt.legend(fontsize=16)
plt.scatter(x, y, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#N=26
y = df_concord_variable['total cost']
x = df_concord_variable['CLAY_max']
#colors = np.random.rand(N)
plt.title("relationship between cost and CLAY_max")
plt.ylabel('cost($)')
plt.xlabel('CLAY_max')
plt.legend(fontsize=16)
plt.scatter(x, y, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#N=26
y = df_concord_variable['total cost']
x = np.log(df_concord_variable['CLAY_max'])
#colors = np.random.rand(N)
plt.title("relationship between cost and Log CLAY_max")
plt.ylabel('cost($)')
plt.xlabel('Log CLAY_max')
plt.legend(fontsize=16)
plt.scatter(x, y, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#N=26
y = df_concord_variable['total cost']
x = np.log(df_concord_variable['CLAY_mean'])
#colors = np.random.rand(N)
plt.title("relationship between cost and Log CLAY_mean")
plt.ylabel('cost($)')
plt.xlabel('Log CLAY_mean')
plt.legend(fontsize=16)
plt.scatter(x, y, alpha=0.5)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
data = df_concord_variable
# use the scatterplot function to build the bubble map
sns.scatterplot(data=data, x=df_concord_variable['CLAY_mean'], y=df_concord_variable['total cost'], size=df_concord_variable['SAND_mean'], legend=False, sizes=(1, 2000))
plt.title("relationship between cost, CLAY_mean and SAND_mean ")
# show the graph
plt.show()

# %%
data = df_concord_variable
# use the scatterplot function to build the bubble map
sns.scatterplot(data=data, x=df_concord_variable['log_CLAY'], y=df_concord_variable['total cost'], size=df_concord_variable['density(#parcel/ft)'], legend=False, sizes=(20, 2000))
plt.title("relationship between cost, Log CLAY_mean and density")
# show the graph
plt.show()

# %%
data = df_concord_variable
# use the scatterplot function to build the bubble map
sns.scatterplot(data=data, x=df_concord_variable['log_CLAY'], y=df_concord_variable['total cost'], size=df_concord_variable['log_density'], legend=False, sizes=(20, 2000))
plt.title("relationship between cost, Log CLAY_mean and Log density")
# show the graph
plt.show()

# %%
#plotting relationship between cost and UNITS_density
y = df_concord_variable['total cost']
x = df_concord_variable['UNITS_density']
#colors = np.random.rand(N)
plt.title("relationship between cost and UNITS_density")
plt.ylabel('cost($)')
plt.xlabel('UNITS_density(#UNITs/ft)')
plt.legend(fontsize=16)
plt.scatter(x, y, alpha=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'UNITS_density'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
